# %%
# %matplotlib inline
import pyvision as pv
import PIL
import numpy as np
import matplotlib.pyplot as plt

# %%
lena = pv.LENA
lena_img = pv.Image(lena)

# %%
lena_PIL = lena_img.asPIL()

# %%
#plt can use subplot for multiple output images
ppl.subplot(221)
x = plt.imshow(lena_PIL)
plt.subplot(222)
y = plt.imshow(lena_PIL, origin="lower")  #specify origin to swap orientation

# %%
lena_np = lena_img.asMatrix2D()
plt.imshow(lena_np.T, cmap="gray")

# %%
from IPython.display import YouTubeVideo, display
vid = YouTubeVideo("TXOR1-fZw64")
display(vid)
